# %%
student_list =["prakash","sarthak","dhruv","saideep"]

print("\nstudent list:")
print(student_list)
# Out:
# student list:
# ['prakash', 'sarthak', 'dhruv', 'saideep']

# %%
student_tuple =("prakash","sarthak","dhruv","saideep")

print("\nstudent Tuple:")
print(student_tuple)
# Out:
# student Tuple:
# ('prakash', 'sarthak', 'dhruv', 'saideep')

# %%
# create dictionary of student
student_dict = {
    101: "prakash",
    102: "sarthak",
    103: "dhruv",
    104: "saideep",
                }
print("student dict")
print(student_dict)
del student_dict[101]
print("\nAfter Deleting:")
print(student_dict)
# Out:
# student dict
# {101: 'prakash', 102: 'sarthak', 103: 'dhruv', 104: 'saideep'}
#
# After Deleting:
# {102: 'sarthak', 103: 'dhruv', 104: 'saideep'}

# %%
student_dict = {
    101: "prakash",
    102: "sarthak",
    103: "dhruv",
    104: "saideep",
                }
print("student dict")
print(student_dict)
student_dict[105] = "yuvraj"
print("\nAfter Adding:")
print(student_dict)
# Out:
# student dict
# {101: 'prakash', 102: 'sarthak', 103: 'dhruv', 104: 'saideep'}
#
# After Adding:
# {101: 'prakash', 102: 'sarthak', 103: 'dhruv', 104: 'saideep', 105: 'yuvraj'}

# %%
student_dict = {
    101: "prakash",
    102: "sarthak",
    103: "dhruv",
    104: "saideep",
                }
print("student dict")
print(student_dict)
student_dict[102] = "sam"
print("\nAfter Updating")
print(student_dict)
# Out:
# student dict
# {101: 'prakash', 102: 'sarthak', 103: 'dhruv', 104: 'saideep'}
#
# After Updating
# {101: 'prakash', 102: 'sam', 103: 'dhruv', 104: 'saideep'}
